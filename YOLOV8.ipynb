# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="LWwJeNXi4ThDQSiI0zTW")
project = rf.workspace("dataset-pubs").project("data-ly3ca")
version = project.version(1)
dataset = version.download("yolov8")

# %%
# %pwd
# %cd /path/to/your/directory
from google.colab import drive
drive.mount('/content/drive')
# !ls /content/drive/MyDrive/

# %%
# !find /content/ -name "data.yaml"

# %%
#  from google.colab import files

# # Upload your data.zip file
# uploaded = files.upload()

# %%
# import zipfile

# # Extract the uploaded zip file
# with zipfile.ZipFile('data.zip', 'r') as zip_ref:
#     zip_ref.extractall('/content/dataset/')

# %%
# %cd /content/
# Out:
# /content

# %%
# !ls
# Out:
# dprd-6	drive  runs  sample_data  wandb  yolov8n.pt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install wandb

# %%
# Log in to your W&B account
import wandb
#api = 49e8082b352b5d87d5a9f213bb08d29215202466

#49e8082b352b5d87d5a9f213bb08d29215202466
wandb.login()

# %%
# !pip install ultralytics

# %%
# !pip uninstall albumentations -y

# %%
# ## # Sample training for n epoch.
# %cd /content/drive/MyDrive/YOLO
EPOCHS = 300
yaml_path = '/content/drive/MyDrive/YOLO/Data-pubs/data.yaml'
# !yolo task=detect mode = train model=yolov8m.pt imgsz=640 data={yaml_path} patience = 0 epochs={EPOCHS} batch=20 workers=4 name=ICCIT_CLAHE_Augment/t_rubaba
